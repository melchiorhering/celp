# %%
import json
from pandas import Series
import pandas as pd
from pandas import DataFrame

# %% [markdown]
# # Business.json

# %%
data_business = [json.loads(line) for line in open('business.json', 'r')]

business_frame = pd.DataFrame(data_business)

new = business_frame.set_index('city')
test = new[:10]
test
# Out:
#                         address  \
# city
# Westlake  30808 Center Ridge Rd
# Westlake         863 Bradley Rd
# Westlake        2004 Crocker Rd
# Westlake       24481 Detroit Rd
# Westlake  26410 Center Ridge Rd
# Westlake       27402 Detroit Rd
# Westlake       30500 Clemens Rd
# Westlake       30651 Detroit Rd
# Westlake  25575 Center Ridge Rd
# Westlake       27112 Detroit Rd
#
#                                                  attributes  \
# city
# Westlake                                               None
# Westlake                                               None
# Westlake  {'GoodForKids': 'False', 'RestaurantsTakeOut':...
# Westlake  {'OutdoorSeating': 'True', 'Alcohol': 'u'full_...
# Westlake                      {'ByAppointmentOnly': 'True'}
# Westlake  {'NoiseLevel': 'u'average'', 'GoodForKids': 'F...
# Westlake  {'RestaurantsPriceRange2': '2', 'BusinessAccep...
# Westlake  {'RestaurantsReservations': 'True', 'WiFi': 'u...
# ...

# %% [markdown]
# # Checkin.json

# %%
data_checkin = [json.loads(line) for line in open('checkin.json', 'r')]

checkin_frame = pd.DataFrame(data_checkin)

checkin_frame[:10]
# Out:
#               business_id                                               date
# 0  -MsRvdPnuw6QuLn5Vxjruw                                2016-02-17 22:58:06
# 1  -ak1fx5L9cNjUE56as12MA  2017-12-30 17:13:44, 2018-02-11 15:36:23, 2018...
# 2  -lAV1uegafxCjGE306kBYQ  2015-07-01 16:49:32, 2015-07-03 13:23:24, 2015...
# 3  -mP3F3srknwKJdJ5FqcX5Q  2010-07-04 04:42:04, 2010-08-22 18:31:16, 2010...
# 4  -pmqS-odJCmxOvWfRFAQ9Q  2011-03-20 21:32:56, 2011-06-27 17:00:25, 2011...
# 5  0I0yATfnNQJB-A-IPGgqDA  2017-07-22 23:27:53, 2017-07-23 13:16:25, 2017...
# 6  0J2QK4Hk8EvJKYGu65qH8w  2010-08-01 14:12:43, 2010-08-15 00:12:10, 2010...
# 7  0VJ8tBxOpD2OxuioVjaAxA  2013-06-26 23:14:30, 2013-06-29 02:44:17, 2013...
# 8  0ZN2MfHyjNIkCx7qJvVhDg  2011-05-25 23:03:12, 2011-05-25 23:10:05, 2011...
# 9  0nAFblolSC3TfbHDq8yjGQ  2011-03-12 23:14:00, 2011-12-03 00:57:28, 2012...

# %% [markdown]
# # Review.json

# %%
data_reviews = [json.loads(line) for line in open('review.json', 'r')]

reviews_frame = pd.DataFrame(data_reviews)

reviews_frame[:10]
# Out:
#               business_id  cool                 date  funny  \
# 0  2lcK3d4K7FU6O8wXdWzOmA     1  2015-10-07 22:34:13      0
# 1  bzdb1jJ1j8Qn_RVHY97FnA     0  2011-10-27 13:11:48      0
# 2  z71IqTCbQW7uzw2H2T1QrA     0  2015-01-18 16:00:39      0
# 3  KR2kRmHnRCaNzOUEGoB25w     1  2015-01-04 01:22:20      0
# 4  z58nyUVyDV-vC7nXFfvR5g     0  2010-05-15 00:58:29      0
# 5  J8klQB6PHeR5vZpz6L0S9w     0  2014-04-19 17:14:38      0
# 6  4wpeWu0lCR_eEdGiyZB9rg     0  2016-08-25 12:16:22      0
# 7  vNPJbqYuJEFDPOLhoq3bFA     0  2017-09-20 14:24:14      0
# 8  nYvBZYg9rfqWFTYuxSVMdw     0  2018-08-23 21:23:42      0
# 9  KR2kRmHnRCaNzOUEGoB25w     1  2014-11-30 02:11:28      0
#
#                 review_id  stars  \
# 0  yO9uwcDlzcFBpp6xSq_wOg    5.0
# 1  ZrQ6PqgZZOcaH8pDlil1ww    2.0
# 2  zVBQuDrIBMPEZHyu9YJjLg    5.0
# 3  HzD24-WZ8pzGGOZeN_ktIA    5.0
# 4  DXGcEtOckOkrs-7HRp4eXQ    3.0
# 5  BHFddF6oZPTHMeFi5mOznA    3.0
# 6  Eg5InhAefmD4NLQsryqQyg    5.0
# ...

# %% [markdown]
# # Tip.json

# %%
data_tip = [json.loads(line) for line in open('tip.json', 'r')]

tip_frame = pd.DataFrame(data_tip)

tip_frame[:10]
# Out:
#               business_id  compliment_count                 date  \
# 0  yBPeUobSSaJQKaYYgiOKYA                 0  2012-07-31 12:05:54
# 1  MWcN6qLWTfRJqLySxwJNqQ                 0  2015-09-12 17:05:52
# 2  uFL4KroMu-dFRsSJrcFzVQ                 0  2012-03-15 20:31:12
# 3  uFL4KroMu-dFRsSJrcFzVQ                 0  2012-03-15 20:29:44
# 4  cbjF6szaq2orE0BplGAKEA                 0  2014-09-08 22:46:58
# 5  HJx0usnyVijOom2q73xGIA                 0  2016-11-24 02:46:00
# 6  uFL4KroMu-dFRsSJrcFzVQ                 0  2012-03-15 20:28:02
# 7  OiR6kP_mAD47vKU1WiPshg                 0  2018-01-21 02:46:25
# 8  rcoAajAVBBXsBNfgKYaH-w                 0  2011-04-26 17:43:56
# 9  yG9SpxEQVIhk6e1o3jbSKg                 0  2010-12-30 22:41:38
#
#                                                 text                 user_id
# 0  For collision estimates, enter through John La...  xtwoOTTOuZrXj4GQtsueuA
# 1      They no longer have the weekend lunch buffet!  0tC5OOTuwvPGnnqhPCoRSw
# ...

# %% [markdown]
# # User.json

# %%
data_user = [json.loads(line) for line in open('user.json', 'r')]

user_frame = pd.DataFrame(data_user)

user_frame[:10]
# Out:
#    average_stars  compliment_cool  compliment_cute  compliment_funny  \
# 0           3.91              756               57               756
# 1           3.62                1                0                 1
# 2           4.35               32                4                32
# 3           2.85                0                0                 0
# 4           4.38                6                0                 6
# 5           3.98               21                2                21
# 6           4.04               15                3                15
# 7           3.56                0                0                 0
# 8           4.46              247                2               247
# 9           3.35              249               31               249
#
#    compliment_hot  compliment_list  compliment_more  compliment_note  \
# 0             366               36               59              541
# ...
